# %% [markdown]
# # Running experiments on Colab
# =

# %% [markdown]
# ## 0. **IMPORTANT:** Make sure runtime uses GPU
# **You will have to restart everything if you forget this.**
# 1. Go to "Runtime" > "change runtime type"
# 2. Select "GPU" for "Hardware accelerator"

# %% [markdown]
# ## 1. Installation on Colab
#
# Run the following commands to install the conda environment on Google Colab

# %%
# Check python before conda installation (keep an eye on the version, should later change) many default packages are installed that we will later remove
# !python --version
# !pip list
# Out:
# Python 3.8.16
# Package                       Version
# ----------------------------- -------
# asttokens                     2.2.1
# atomicwrites                  1.4.0
# attrs                         22.1.0
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# beautifulsoup4                4.12.2
# bleach                        6.0.0
# colorama                      0.4.6
# condacolab                    0.1.6
# contourpy                     1.0.7
# cycler                        0.11.0
# Cython                        0.29.33
# debugpy                       1.5.1
# decorator                     5.1.1
# defusedxml                    0.7.1
# executing                     1.2.0
# fastjsonschema                2.16.3
# fonttools                     4.39.3
# importlib-metadata            6.6.0
# importlib-resources           5.12.0
# iniconfig                     1.1.1
# ipykernel                     6.15.0
# ipython                       8.4.0
# ipython-genutils              0.2.0
# jedi                          0.18.2
# Jinja2                        3.1.2
# json5                         0.9.11
# jsonschema                    4.17.3
# jupyter_client                8.2.0
# jupyter_core                  5.3.0
# jupyterlab-pygments           0.2.2
# kiwisolver                    1.4.4
# MarkupSafe                    2.1.2
# matplotlib                    3.7.1
# matplotlib-inline             0.1.6
# mistune                       2.0.5
# nbclient                      0.7.4
# nbconvert                     7.4.0
# nbformat                      5.8.0
# nbmerge                       0.0.4
# nest-asyncio                  1.5.6
# numpy                         1.24.2
# packaging                     23.0
# pandocfilters                 1.5.0
# parso                         0.8.3
# pickleshare                   0.7.5
# Pillow                        9.5.0
# pip                           23.0.1
# pkgutil_resolve_name          1.3.10
# platformdirs                  3.5.0
# pluggy                        1.0.0
# prompt-toolkit                3.0.38
# psutil                        5.9.0
# pure-eval                     0.2.2
# py                            1.11.0
# Pygments                      2.15.1
# pyparsing                     3.0.9
# pyrsistent                    0.19.3
# pytest                        7.1.2
# python-dateutil               2.8.2
# pytz                          2023.3
# pywin32                       306
# pyzmq                         25.0.2
# setuptools                    66.0.0
# six                           1.16.0
# soupsieve                     2.4.1
# stack-data                    0.6.2
# swig                          4.1.1
# tinycss2                      1.2.1
# tomli                         2.0.1
# torch                         1.8.1
# torchvision                   0.9.1
# tornado                       6.2
# tqdm                          4.65.0
# traitlets                     5.9.0
# typing_extensions             4.5.0
# wcwidth                       0.2.6
# webencodings                  0.5.1
# wheel                         0.38.4
# y-py                          0.5.9
# zipp                          3.15.0

# %%
# Install conda (we will be using Mamba instead of anaconda/miniconda, but it shouldn't matter)
# Kernel should restart after this. Don't run the above cells again. Just keep going to the next cells
# !pip install -q condacolab
# import condacolab
# condacolab.install()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\omery\anaconda3\envs\hw2_env_cpu\lib\site-packages\condacolab.py:26, in <module>
#      25 try:
# ---> 26     import google.colab
#      27 except ImportError:
#
# ModuleNotFoundError: No module named 'google'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# c:\Users\omery\GitHub\Convolution-Neural-Networks---HW2\run_experiments_on_colab.ipynb Cell 5 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/c%3A/Users/omery/GitHub/Convolution-Neural-Networks---HW2/run_experiments_on_colab.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> # Install conda (we will be using Mamba instead of anaconda/miniconda, but it shouldn't matter)
#       <a href='vscode-notebook-cell:/c%3A/Users/omery/GitHub/Convolution-Neural-Networks---HW2/run_experiments_on_colab.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> # Kernel should restart after this. Don't run the above cells again. Just keep going to the next cells
#       <a href='vscode-notebook-cell:/c%3A/Users/omery/GitHub/Convolution-Neural-Networks---HW2/run_experiments_on_colab.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> # !pip install -q condacolab
# ----> <a href='vscode-notebook-cell:/c%3A/Users/omery/GitHub/Convolution-Neural-Networks---HW2/run_experiments_on_colab.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a> import condacolab
#       <a href='vscode-notebook-cell:/c%3A/Users/omery/GitHub/Convolution-Neural-Networks---HW2/run_experiments_on_colab.ipynb#W4sZmlsZQ%3D%3D?line=4'>5</a> condacolab.install()
#
# File c:\Users\omery\anaconda3\envs\hw2_env_cpu\lib\site-packages\condacolab.py:28, in <module>
#      26     import google.colab
#      27 except ImportError:
# ---> 28     raise RuntimeError("This module must ONLY run as part of a Colab notebook!")
#      31 __version__ = "0.1.6"
#      32 __author__ = "Jaime Rodríguez-Guerra <jaimergp@users.noreply.github.com>"
#
# RuntimeError: This module must ONLY run as part of a Colab notebook!

# %%
# Check conda is installed
# import condacolab
# condacolab.check()

# !conda --version

# %%
# Check python again (version should change slightly) should be only a few packages installed and conda should be listed
# !python --version
# !pip list

# %% [markdown]
# ## 2. Set up conda environment
#
# For this step, you need to upload environment.yml.
# 1. At the bar on the left (where "Table of Content" is shown), click on the file icon below.
# 2. Click on the "Upload to session storage" icon.
# 3. Locate the "environment.yml" file an upload it.
# 4. The file should be visible in the "Files" panel.
# 5. Run the below command.

# %%
# !mamba env update -n base -f environment.yml

# %%
# Check python for the last time (version should be 3.7.4 according to our file) all packages should be installed
# !python --version
# !pip list

# %% [markdown]
# ## 3. Run experiments
#
# 1. Upload hw2 folder and helpers folder with their contents. (the same way you uploaded the environment.yml file.
# 2. Define the experiment you want to run.
# 3. Run the experiment.
#
# Note: You can either use the console command or import run_experiments and run the cell. Select the one you prefer.
#
# Note: When done, remember to download the json files in the "results" folder.

# %%
# Run console command
# !python -m hw2.experiments run-exp -n "test_run" --seed 42 --bs-train 128 --epochs 10 --early-stopping 5 -K 32 -L 1 -P 1 -H 100

# %%
# Run cell
# from hw2.experiments import run_experiment
# seed = 42
# run_experiment(
#     'test_run', 
#     seed=seed, 
#     bs_train=128, 
#     epochs=10, 
#     early_stopping=5,
#     filters_per_layer=[32], 
#     layers_per_block=1, 
#     pool_every=1, 
#     hidden_dims=[100],
# )
